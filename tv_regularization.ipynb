# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from utils import gradients_color_parallel as g

# %%
im_bgr = cv2.imread('hedgehog.jpg')
#im = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)
im = im_bgr.astype(np.float)

# %%
noise = np.random.normal(0,0.1*(np.max(im)-np.min(im)),im.shape)

# %%
plt.imshow((im+noise)/255.0)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
beta = 1.0
dt = beta/4 * 0.9

# %%
im = im+noise

# %%
# %%time
for iteration in range(10):
    
    im = g.iterations(im, 10, dt, beta)

    cv2.imwrite('test/tv_reg_4_'+str((iteration+1)*10)+'.jpg', im)
# Out:
# CPU times: user 5min 30s, sys: 24.8 s, total: 5min 55s
# Wall time: 2min 8s

# %% [raw]
# %matplotlib notebook
#
# from mpl_toolkits.mplot3d import Axes3D
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
#
# (size_x, size_y) = im.shape
# x, y = np.meshgrid(np.linspace(0,1,size_y), np.linspace(0,1,size_x))
#
# ax.plot_surface(x, y, Iy, cmap='coolwarm')
