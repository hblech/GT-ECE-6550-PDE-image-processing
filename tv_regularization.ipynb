# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from utils import gradients_color_parallel as g

# %%
im_bgr = cv2.imread('hedgehog.jpg')
#im = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)
im = im_bgr.astype(np.float)

# %%
noise = np.random.normal(0,0.3*(np.max(im)-np.min(im)),im.shape)

# %%
plt.imshow((im+noise)/255.0)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
beta = 1.0
dt = beta/4 # maximum value according to CFL condition

# %%
im = im+noise
cv2.imwrite('test/tv_reg_0.jpg', im)
# Out:
# True

# %%
# %%time
for iteration in range(50):
    
    im = g.iterations(im, 10, dt, beta)

    cv2.imwrite('test/tv_reg_'+str((iteration+1)*10)+'.jpg', im)
# Out:
# CPU times: user 27min 38s, sys: 2min 5s, total: 29min 43s
# Wall time: 10min 44s

# %% [raw]
# %matplotlib notebook
#
# from mpl_toolkits.mplot3d import Axes3D
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
#
# (size_x, size_y) = im.shape
# x, y = np.meshgrid(np.linspace(0,1,size_y), np.linspace(0,1,size_x))
#
# ax.plot_surface(x, y, Iy, cmap='coolwarm')
